# %% [markdown]
# <a href="https://colab.research.google.com/github/buriihenry/Drugs-Recommendation/blob/master/Drugs_Recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the data

train = pd.read_csv('drive/My Drive/Projects/drugsComTrain_raw.csv')
test = pd.read_csv('drive/My Drive/Projects/drugsComTest_raw.csv')

# getting the shapes
print("Shape of train :", train.shape)
print("Shape of test :", test.shape)
# Out:
# Shape of train : (161297, 7)
# Shape of test : (53766, 7)

# %%
train.head()
# Out:
#    uniqueID                  drugName  ...       date usefulCount
# 0    206461                 Valsartan  ...  20-May-12          27
# 1     95260                Guanfacine  ...  27-Apr-10         192
# 2     92703                    Lybrel  ...  14-Dec-09          17
# 3    138000                Ortho Evra  ...   3-Nov-15          10
# 4     35696  Buprenorphine / naloxone  ...  27-Nov-16          37
#
# [5 rows x 7 columns]

# %%
train.head()
# Out:
#    uniqueID                  drugName  ...       date usefulCount
# 0    206461                 Valsartan  ...  20-May-12          27
# 1     95260                Guanfacine  ...  27-Apr-10         192
# 2     92703                    Lybrel  ...  14-Dec-09          17
# 3    138000                Ortho Evra  ...   3-Nov-15          10
# 4     35696  Buprenorphine / naloxone  ...  27-Nov-16          37
#
# [5 rows x 7 columns]

# %%
#combining both the train and Test dataset
data=pd.concat([train,test])

#checking the shape
data.shape
# Out:
# (215063, 7)

# %%
#checking the sample of new dataset
data.sample(5)
# Out:
#        uniqueID                          drugName  ...       date usefulCount
# 39179     18091  Ethinyl estradiol / etonogestrel  ...  10-Nov-11           0
# 84872     69576                     Buprenorphine  ...   2-Oct-13          76
# 22547     87734                          Naproxen  ...  31-Jul-09          23
# 64674    192359  Drospirenone / ethinyl estradiol  ...  10-May-15          20
# 43962     52726                         Zolpimist  ...  10-Oct-11           5
#
# [5 rows x 7 columns]

# %%
#describing the data
data.describe()
# Out:
#             uniqueID         rating    usefulCount
# count  215063.000000  215063.000000  215063.000000
# mean   116039.364814       6.990008      28.001004
# std     67007.913366       3.275554      36.346069
# min         0.000000       1.000000       0.000000
# 25%     58115.500000       5.000000       6.000000
# 50%    115867.000000       8.000000      16.000000
# 75%    173963.500000      10.000000      36.000000
# max    232291.000000      10.000000    1291.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 215063 entries, 0 to 53765
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   uniqueID     215063 non-null  int64
#  1   drugName     215063 non-null  object
#  2   condition    213869 non-null  object
#  3   review       215063 non-null  object
#  4   rating       215063 non-null  int64
#  5   date         215063 non-null  object
#  6   usefulCount  215063 non-null  int64
# dtypes: int64(3), object(4)
# memory usage: 13.1+ MB

# %%
#checking for null values
data.isnull().sum()
# Out:
# uniqueID          0
# drugName          0
# condition      1194
# review            0
# rating            0
# date              0
# usefulCount       0
# dtype: int64

# %%
# most common condition 
from wordcloud import WordCloud
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

wordcloud = WordCloud(background_color = 'lightblue', stopwords = stopwords, max_words = 100, width = 1200, height = 800).generate(str(data['drugName']))

plt.rcParams['figure.figsize'] = (15, 15)
plt.title('Most Common Conditions among the Patients', fontsize = 30)
print(wordcloud)
plt.axis('off')
plt.imshow(wordcloud)
plt.show()
# Out:
# <wordcloud.wordcloud.WordCloud object at 0x7f0fa29aab10>
